# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlOTE5MGRlOTUzNjU0NGVmNDhiYjdkN2MyZDRlYzI2YSIsInN1YiI6IjY1YjczYjAzMzEyMzQ1MDE2MmRiMDdmMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.xjVrLQr6b9EEO_PeHo1L0LsteuMdvEETrwfpv9Roocs"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":128.87,"poster_path":"/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.711,"vote_count":25446},{"adult":false,"backdrop_path":"/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fiction
# ...

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 128.87,
#    'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.711,
#    'vote_count': 25446},
#   {'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
# ...

# %%
import pandas as pd
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 1   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg   [18, 36, 10752]     424
# 4   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 5   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 6   False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg   [16, 10751, 14]     129
# 7   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
## Used to extract only three or selected columns
df = pd.DataFrame(response.json()['results'])[['id', 'title', 'original_title']]
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5    19404                    Dilwale Dulhania Le Jayenge
# 6      129                                  Spirited Away
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
## We have 457 pages we need a loop to extract all the data from all the pages
import requests
import pandas as pd
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlOTE5MGRlOTUzNjU0NGVmNDhiYjdkN2MyZDRlYzI2YSIsInN1YiI6IjY1YjczYjAzMzEyMzQ1MDE2MmRiMDdmMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.xjVrLQr6b9EEO_PeHo1L0LsteuMdvEETrwfpv9Roocs"
}

for i in range(1, 50):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'original_title']]
    df = df._append(temp_df, ignore_index = True)

# %%
df
# Out:
#         id                     title            original_title
# 0      278  The Shawshank Redemption  The Shawshank Redemption
# 1      238             The Godfather             The Godfather
# 2      240     The Godfather Part II     The Godfather Part II
# 3      424          Schindler's List          Schindler's List
# 4      389              12 Angry Men              12 Angry Men
# ..     ...                       ...                       ...
# 995    769                GoodFellas                GoodFellas
# 996    346             Seven Samurai                      七人の侍
# 997  12477    Grave of the Fireflies                     火垂るの墓
# 998    637         Life Is Beautiful           La vita è bella
# 999  11216           Cinema Paradiso     Nuovo Cinema Paradiso
#
# [1000 rows x 3 columns]

# %%
df.to_csv("Top_Rated_Movies.csv")

# %%
df1 = pd.read_csv("Top_Rated_Movies.csv")

# %%
df1.head(5)
# Out:
#    Unnamed: 0   id                     title            original_title
# 0           0  278  The Shawshank Redemption  The Shawshank Redemption
# 1           1  238             The Godfather             The Godfather
# 2           2  240     The Godfather Part II     The Godfather Part II
# 3           3  424          Schindler's List          Schindler's List
# 4           4  389              12 Angry Men              12 Angry Men
